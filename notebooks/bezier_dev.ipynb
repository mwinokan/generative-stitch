# %%
# %load_ext autoreload
# %autoreload 2
import mrich
from mrich import print

import bezier
import numpy as np
import matplotlib.pyplot as plt
from stitch import Canvas, Bezier
from stitch.bezier import optimise_coords

# %%
c = Canvas()
c

# %%
curve1 = Bezier.from_coords([
    [0.0,0.0],
    [0.5,1.0],
    [1.0,0.0],
])
curve1.plot()
# Out:
# <Axes: >

# %%
curve = Bezier.random(52, optimise=True)
curve.plot(lines=False, nodes=False)
# Out:
# <Axes: >

# %%
print(curve.coords)
# Out:
# ╭──────────────────────────────────────────────╮
# │  0.780512316427372     0.9101288648249138    │
# │  0.744647127547786     0.9312120712829706    │
# │  0.5979098570860655    0.9325952763079403    │
# │  0.4745793166975044    0.8831164427542273    │
# │  0.42005960156785793   0.8189728711772551    │
# │  0.24872772159686096   0.9656512349374313    │
# │  0.20259550181140573   0.9555250372335797    │
# │  0.2768624937454297    0.8560304425462198    │
# │  0.24200237969340144   0.7304931062824094    │
# │  0.1628928397689453    0.5923200270504267    │
# │  0.05575760549031272   0.6440273384918621    │
# │  0.013314569491119643  0.6112590996291027    │
# │  0.015488388532776898  0.43016934391705086   │
# │  0.062249321873242836  0.43305333188553874   │
# │  0.1591982185155919    0.39908549884774935   │
# │  0.11443459254369714   0.3026152192569638    │
# │  0.0444894369111386    0.21782884171059025   │
# │  0.034456509191861606  0.06691332912078685   │
# ...

# %%
curve.write_coords("curve2.csv")
# Out:
#  DISK  Writing curve2.csv...

# %%
curve1 = Bezier.from_coords("curve1.json")
curve1.plot()
# Out:
# <Axes: >

# %%
Bezier.from_coords([
    [0.0, 0.0],
    [1.0, 1.0],
    [2.0, 1.0],
    [3.0, 0.5],
    [4.0, 0.5],
]).plot()
# Out:
# <Axes: >

# %%
curve1.radius = 3
curve1.to_svg("curve1_fit.svg")
# Out:
#  DISK  Writing curve1_fit.svg...
